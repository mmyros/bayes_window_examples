# %% [markdown]
# # LFP example with stim strength

# %%
import numpy as np
import pandas as pd
from bayes_window import BayesWindow, BayesRegression
from bayes_window.generative_models import generate_fake_lfp

# %% [markdown]
# ## ISI

# %%
df = []
for slope in np.linspace(4, 40, 4):
    df1 = generate_fake_lfp(mouse_response_slope=slope)[0]
    df1['stim_strength'] = slope
    df.append(df1)
df = pd.concat(df)

BayesWindow(df=df, y='isi', treatment='stim_strength', group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.LayerChart(...)

# %%
window = BayesRegression(df=df, y='isi', treatment='stim_strength', group='mouse', detail='i_trial')
window.fit(add_group_slope=False, dist_y='gamma')
window.chart
# Out:
# alt.LayerChart(...)

# %%
window.explore_model_kinds()
# Out:
#                            rank         loo      p_loo       d_loo  \
# full                          0  949.068104  10.345094    0.000000
# with_group_slope              1  934.249693   9.764845   14.818410
# no_condition_or_treatment     2  840.006765   2.409009  109.061338
# no-treatment                  3  826.414081   2.375001  122.654023
# no_condition                  4  614.744346   1.418238  334.323758
# no_group                      5  604.915502   1.381341  344.152602
#
#                                  weight         se        dse  warning  \
# full                       5.731222e-01  14.659574   0.000000    False
# with_group_slope           4.195967e-01  14.979551  19.720584    False
# no_condition_or_treatment  7.281117e-03  14.196898  20.185582    False
# no-treatment               0.000000e+00  14.794070  21.152962    False
# no_condition               5.716256e-10  11.690279  18.268653    False
# no_group                   4.292185e-09  12.075930  19.780906    False
#
#                           loo_scale
# full                            log
# with_group_slope                log
# no_condition_or_treatment       log
# no-treatment                    log
# no_condition                    log
# no_group                        log

# %%
## Power

# %% [markdown]
# ## Power

# %%
df = []
for slope in np.linspace(4, 400, 4):
    df1 = generate_fake_lfp(mouse_response_slope=slope)[0]
    df1['stim_strength'] = slope
    df.append(df1)
df = pd.concat(df)

BayesWindow(df=df, y='Power', treatment='stim_strength', group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.LayerChart(...)

# %%
window = BayesRegression(df=df, y='Power', treatment='stim_strength', group='mouse', detail='i_trial')
window.fit(add_group_slope=False, dist_y='gamma')
window.chart
# Out:
# alt.LayerChart(...)

# %%
window = BayesRegression(df=df, y='Power', treatment='stim_strength', condition='mouse', detail='i_trial')
window.fit(add_condition_slope=True, center_intercept=True, dist_y='gamma')
window.chart
# Out:
# alt.LayerChart(...)

# %%
window.explore_model_kinds()
# Out:
#                            rank           loo       p_loo         d_loo  \
# no_group                      0  -8382.918977  148.883034      0.000000
# no_condition                  1  -9543.622766  173.428688   1160.703789
# no-treatment                  2 -12851.724835  289.906794   4468.805859
# full                          3 -30119.660441  785.946146  21736.741465
# no_condition_or_treatment     4 -30548.840106  694.892918  22165.921129
#
#                              weight            se           dse  warning  \
# no_group                   0.266394   1263.482947      0.000000     True
# no_condition               0.298179   1842.600276   2271.454217     True
# no-treatment               0.068044   5864.374968   6026.064434     True
# full                       0.316497  25791.116094  25842.952738    False
# no_condition_or_treatment  0.050886  25975.341898  26025.252126    False
#
#                           loo_scale
# no_group                        log
# no_condition                    log
# no-treatment                    log
# full                            log
# no_condition_or_treatment       log

# %%
window.explore_models()
# Out:
#                            rank           loo       p_loo         d_loo  \
# no_condition_or_treatment     0 -11053.362640  185.471048      0.000000
# full_normal                   1 -12635.495863  281.102331   1582.133223
# full_lognormal                2 -13547.244827  312.230904   2493.882187
# full_student                  3 -14764.862264  364.165336   3711.499623
# no_group                      4 -14880.625071  365.576683   3827.262430
# no-treatment                  5 -30310.229073  781.846198  19256.866432
# full_exponential              6 -31454.254209  724.041235  20400.891568
# no_condition                  7 -31849.715457  733.567089  20796.352817
# full_gamma                    8 -31999.623728  773.256811  20946.261087
#
#                                  weight            se           dse  warning  \
# no_condition_or_treatment  0.000000e+00   1932.861308      0.000000     True
# full_normal                2.002023e-01   5155.228620   5536.375366     True
# full_lognormal             1.682372e-01   5256.255639   5586.252505     True
# full_student               1.890542e-01   6270.532588   6575.797507     True
# no_group                   2.164037e-01   6205.944984   6527.188961     True
# no-treatment               5.770332e-13  26232.640517  26330.152019    False
# full_exponential           9.436303e-02  24515.855857  24620.252844     True
# no_condition               9.418422e-02  24254.809604  24358.349996     True
# full_gamma                 3.755541e-02  24035.552877  24110.650275     True
#
#                           loo_scale
# no_condition_or_treatment       log
# full_normal                     log
# full_lognormal                  log
# full_student                    log
# no_group                        log
# no-treatment                    log
# full_exponential                log
# no_condition                    log
# full_gamma                      log

# %%
window.explore_models()
# Out:
#                            rank           loo       p_loo         d_loo  \
# full_exponential              0 -14428.058358  372.307082      0.000000
# no_condition_or_treatment     1 -30682.624106  794.053832  16254.565748
# no_group                      2 -31065.327005  792.949352  16637.268647
# full_lognormal                3 -31220.711932  848.772088  16792.653574
# no_condition                  4 -31224.108958  788.088244  16796.050600
# full_normal                   5 -31248.691716  758.527297  16820.633358
# full_student                  6 -31312.725778  799.816464  16884.667419
# no-treatment                  7 -31623.633331  772.672505  17195.574973
# full_gamma                    8 -31967.638652  795.947182  17539.580294
#
#                                  weight            se           dse  warning  \
# full_exponential           2.325016e-01   6462.748885      0.000000     True
# no_condition_or_treatment  1.823080e-10  25823.975563  26660.044977    False
# no_group                   1.381919e-01  24950.710961  25767.373897     True
# full_lognormal             8.930785e-02  24754.429097  25614.731812     True
# no_condition               1.446949e-01  24841.429812  25710.892002     True
# full_normal                1.855162e-01  24726.723991  25599.991563     True
# full_student               1.226542e-01  24685.565468  25560.903735     True
# no-treatment               1.644919e-10  25043.714403  25904.703562     True
# full_gamma                 8.713333e-02  24029.064600  24905.286310     True
#
#                           loo_scale
# full_exponential                log
# no_condition_or_treatment       log
# no_group                        log
# full_lognormal                  log
# no_condition                    log
# full_normal                     log
# full_student                    log
# no-treatment                    log
# full_gamma                      log

# %%
window.explore_models()
# Out:
#                            rank           loo       p_loo         d_loo  \
# no_condition_or_treatment     0  -9962.497679  181.928756      0.000000
# full_student                  1 -10216.458355  202.873075    253.960676
# no_condition                  2 -10221.896906  195.883746    259.399227
# full_lognormal                3 -12528.072625  289.307184   2565.574946
# full_normal                   4 -13131.084961  323.588753   3168.587282
# no_group                      5 -15399.578538  365.427186   5437.080859
# full_gamma                    6 -31145.239790  725.810752  21182.742111
# no-treatment                  7 -31264.726420  758.174420  21302.228742
# full_exponential              8 -32223.172225  828.929372  22260.674546
#
#                                  weight            se           dse  warning  \
# no_condition_or_treatment  4.077320e-03   1967.083406      0.000000     True
# full_student               1.486777e-01   1798.206156   2706.684288     True
# no_condition               2.184734e-01   1958.425085   2742.473233     True
# full_lognormal             2.495443e-01   5229.910197   5616.121134     True
# full_normal                1.653863e-01   5426.848092   5806.941753     True
# no_group                   9.983109e-02   5917.573186   6135.312164     True
# full_gamma                 1.083748e-01  24825.949740  24927.581818     True
# no-treatment               1.911429e-10  25380.867843  25483.766745     True
# full_exponential           5.635172e-03  23938.034894  24041.486055     True
#
#                           loo_scale
# no_condition_or_treatment       log
# full_student                    log
# no_condition                    log
# full_lognormal                  log
# full_normal                     log
# no_group                        log
# full_gamma                      log
# no-treatment                    log
# full_exponential                log
