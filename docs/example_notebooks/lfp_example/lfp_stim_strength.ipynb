# %% [markdown]
# # LFP example with stim strength

# %%
from bayes_window import models, fake_spikes_explore, BayesWindow
from bayes_window.generative_models import generate_fake_lfp
from importlib import reload
import numpy as np
import altair as alt
import pandas as pd

# %% [markdown]
# ## ISI

# %%
df=[]
for slope in np.linspace(4,40,4):
    df1=generate_fake_lfp(mouse_response_slope=slope)[0]
    df1['stim_strength']=slope
    df.append(df1)
df=pd.concat(df)


BayesWindow(df, 'isi', treatment='stim_strength',  group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.LayerChart(...)

# %%
window=BayesWindow(df, 'isi', treatment='stim_strength',  group='mouse', detail='i_trial')
window.fit_slopes(add_group_slope=False,dist_y='gamma')
window.chart
# Out:
# alt.LayerChart(...)

# %%
window.explore_model_kinds()
# Out:
#                            rank         loo      p_loo       d_loo  \
# with_group_slope              0  937.837040  10.640128    0.000000
# full                          1  925.047298  10.685472   12.789742
# no-treatment                  2  849.185205   2.126086   88.651835
# no_condition_or_treatment     3  823.481915   2.856184  114.355126
# no_condition                  4  609.558290   1.267439  328.278750
# no_group                      5  609.158263   1.359824  328.678778
#
#                                  weight         se        dse  warning  \
# with_group_slope           5.350872e-01  17.583232   0.000000    False
# full                       4.649128e-01  17.922111  25.637421    False
# no-treatment               7.794005e-12  12.810844  21.194117    False
# no_condition_or_treatment  7.302553e-12  16.091755  23.681719    False
# no_condition               2.948952e-09  12.013955  20.834724    False
# no_group                   1.695717e-08  11.856016  21.117489    False
#
#                           loo_scale
# with_group_slope                log
# full                            log
# no-treatment                    log
# no_condition_or_treatment       log
# no_condition                    log
# no_group                        log

# %%
## Power

# %% [markdown]
# ## Power

# %%
df=[]
for slope in np.linspace(4,400,4):
    df1=generate_fake_lfp(mouse_response_slope=slope)[0]
    df1['stim_strength']=slope
    df.append(df1)
df=pd.concat(df)


BayesWindow(df, 'Power', treatment='stim_strength',  group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.LayerChart(...)

# %%
window=BayesWindow(df, 'Power', treatment='stim_strength',  group='mouse', detail='i_trial')
window.fit_slopes(add_group_slope=False,dist_y='gamma')
window.chart
# Out:
# alt.LayerChart(...)

# %%
from importlib import reload
from bayes_window import workflow
reload(workflow)

window=workflow.BayesWindow(df, 'Power', treatment='stim_strength',  condition='mouse', detail='i_trial')
window.fit_slopes(add_condition_slope=True,center_intercept=True,dist_y='gamma')
window.chart
# Out:
#                            rank           loo       p_loo         d_loo  \
# no_condition                  0 -7.191709e+03  219.552926  0.000000e+00
# no_condition_or_treatment     1 -8.321811e+03  258.855133  1.130102e+03
# no-treatment                  2 -1.026739e+04  315.711161  3.075685e+03
# no_group                      3 -3.231009e+06    0.000000  3.223817e+06
# full                          4 -3.254435e+06    0.000000  3.247243e+06
#
#                              weight            se           dse  warning  \
# no_condition               0.388470  3.560917e+03  0.000000e+00     True
# no_condition_or_treatment  0.417983  3.639718e+03  5.110383e+03     True
# no-treatment               0.103917  5.746622e+03  6.779148e+03     True
# no_group                   0.052652  3.212527e+06  3.212545e+06     True
# full                       0.036978  3.226879e+06  3.226897e+06     True
#
#                           loo_scale
# no_condition                    log
# no_condition_or_treatment       log
# no-treatment                    log
# no_group                        log
# full                            log

# %%
window.explore_model_kinds()
# Out:
#                            rank           loo        p_loo         d_loo  \
# no-treatment                  0 -12273.520877   253.007329      0.000000
# no_condition                  1 -18599.310650   442.444029   6325.789773
# no_group                      2 -55818.496777  1103.237846  43544.975900
# no_condition_or_treatment     3 -55946.967754   963.120636  43673.446877
# full                          4 -57440.559317  1109.317119  45167.038440
#
#                              weight            se           dse  warning  \
# no-treatment               0.047719   3636.980301      0.000000     True
# no_condition               0.301395   9825.662387  10505.821993     True
# no_group                   0.309405  51683.192984  51837.025583    False
# no_condition_or_treatment  0.074914  51504.745403  51665.868968     True
# full                       0.266568  50093.662496  50252.302234     True
#
#                           loo_scale
# no-treatment                    log
# no_condition                    log
# no_group                        log
# no_condition_or_treatment       log
# full                            log

# %%
window.explore_models()

# %%
window.explore_models()

# %%
window.explore_models()
